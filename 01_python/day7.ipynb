# %% [markdown]
# # **FUNCTIONS**

# %%
# create a function(with docstring)

def odd_even(i):
    if i%2==0:
        return 'even'
    else:
        return 'odd'

# %%
# calling the fuction

for i in range(1,11):
    x=odd_even(i)
    print(x)
# Out:
# odd
# even
# odd
# even
# odd
# even
# odd
# even
# odd
# even

# %%
# to make the function like a senior programmer, so that people dont catch errors easily

def odd_even(i):
    if type(i)==int:
        if i%2==0:
            return 'even'
        else:
            return 'odd'
    else:
        return 'stupid or what'
    

x=odd_even('hello')
print(x)
# Out:
# stupid or what

# %% [markdown]
# # Parameters Vs Arguments

# %% [markdown]
# Types of Arguments
# - Default Argument
# - Positional Argument
# - Keyword Argument

# %%
# default argument - in case someone forgets to put value in arguments so parameters already have a default value to use to avoid errors

def power(a=1,b=1):
    """This function returns the exponential result of 2 numbers given. first number would be raised to the second number
    created- 14/05/26
    """
    return a**b

power()
# Out:
# 1

# %%
# to check the documentation of a user made function
power.__doc__
# Out:
# 'This function returns the exponential result of 2 numbers given. first number would be raised to the second number\n    created- 14/05/26\n    '

# %%
# positional argument - first argument goes to first parameter, second to second. its default in python to work that way
power(2,3)
# Out:
# 8

# %%
# keyword argument - if u forget which place which parameter exists, use this

power(b=4,a=5)
# Out:
# 625

# %% [markdown]
# # *args and **kwargs

# %%
# *args - if you dont want to set a limit on the no of arguments and user can put as many as they want

def multiply(*args): # can put anything after * like *eshel, *whatever etc
    product=1
    for i in args:
        product=product*i
    return product


multiply(1,2,3,4,5,6)
# Out:
# 720

# %%
# **kwargs
# **kwargs allows us to pass any number of keyword arguments.
# Keyword arguments mean that they contain a key-value pair, like a Python dictionary.

# %%
def display(**kwargs):
    for (key, value) in kwargs.items():
        print(key, '->', value)

display(india='delhi', pakistan='islamabad',france='paris')
# Out:
# india -> delhi
# pakistan -> islamabad
# france -> paris

# %% [markdown]
# Points to remember while using *args and **kwargs
# - order of the arguments matter(normal -> *args -> **kwargs) (SEE BELOW CODE)
# - The words “args” and “kwargs” are only a convention, you can use any name of your choice

# %%
def display(name, *args, **kwargs):
    print('name:', name)
    print('args:', args)
    print('kwargs:',kwargs)

display("Eshel", "python", "ML", age=20, city="delhi")
# Out:
# name: Eshel
# args: ('python', 'ML')
# kwargs: {'age': 20, 'city': 'delhi'}

# %% [markdown]
# Without return statement
# - if returns nothing and you put the function in print while calling -> prints None

# %%
# eg:
list1=[1,2,3,4]
print(list1.append(5)) # gives none as append function doesnt return anything, it changes the list itself
# Out:
# None

# %% [markdown]
# Global and Local variable scope
# - global variable is outside the function, local is inside
# - global can be used inside function but local cant be used outside the function

# %%
def g(y):
    print(x)
    print(x+1)
x = 5
g(x)
print(x)
# Out:
# 5
# 6
# 5

# %%
def h(y):
    x += 1
    
x= 5
h(x)
print(x)  # GIVESS ERRORRRR - SEE EXPLANATION BELOW

# %% [markdown]
# - x += 1 is shorthand for x = x + 1.
# - The moment Python sees x = inside the function, it treats x as a local variable.
# - But locally, x has no value yet
# - The global x = 5 is completely ignored inside the function.
# - for this problem, use global keyword

# %%
def h(y):
    global x # bad practice tho
    x += 1 # modifies the x globally/outside as well due to global keyword before this so we get 6 not 5
    
x= 5
h(x)
print(x)
# Out:
# 6

# %%
def f(x):
   x = x + 1
   print('in f(x): x =', x)
   return x

x = 3
z = f(x)
print('in main program scope: z =', z)
print('in main program scope: x =', x) # gives 3 as global keyword wasnt used inside the functions so global x variable didnt get any changes
# Out:
# in f(x): x = 4
# in main program scope: z = 4
# in main program scope: x = 3

# %% [markdown]
# Nested loop

# %%
def f():
    def g():
        print('inside function g') # o/p prints this in infinite loop as f is called so f part of def will be skipped as f function as g function and that g function hasnt been called yet and g will be called
        f()                        # then print statement then f called -> repeats

    g()
    print('inside function f')

f()

# %%
def g(x):
    def h():
        x = 'abc'
    x = x + 1
    print('in g(x): x =', x)
    h()
    return x

x = 3
z = g(x)
print(z)
# Out:
# in g(x): x = 4
# 4

# %% [markdown]
# # Functions are 1st class citizens
# - meaning, they act and behave as any other datatypes.
# - anything we can do with datatypes, we can do with functions
# - python is the only program that allows this

# %%
# type and id
def square(num):
  return num**2

print(type(square))

print(id(square))
# Out:
# <class 'function'>
# 1850813059840

# %%
# reassign
def square(num):
  return num**2

x = square
x(3) # instead of square(3) we can do this

# similar to a=2 
# b=a 
# print(b)
# 2
# Out:
# 9

# %%
# deleting a function
del square

# %%
# storing a function
L=[1,2,3,4,square]
print(L[4](3))
# Out:
# 9

# %%
# checking if functions are mutable or immutable - store in set and see as mutable objects arent allowed inside
s={square}
# works so immutable

# %% [markdown]
# Returning a function

# %%
def f():
    def x(a,b):
        return a+b
    return x

val=f()(3,4) # after the return x line, it takes the x function and replaces it with f() as its returning to f() and it becomes x(3,4)
print(val)
# Out:
# 7

# %% [markdown]
# function as argument

# %%
def func_a():
    print('inside function a')

def func_b(x):
    print('inside function b')
    return x()

print(func_b(func_a))
# Out:
# inside function b
# inside function a
# None

# %% [markdown]
# # Lambda Function
# - very imp for data science

# %% [markdown]
# ### Lambda Function
#
# A lambda function is a small anonymous function.
#
# A lambda function can take any number of arguments, but can only have one expression.
#
# ![image.png](data:image/png;base64,...)

# %%
# x -> x^2

lambda x:x**2
# Out:
# <function __main__.<lambda>(x)>

# %%
# x,y -> x+y

a=lambda x,y:x+y
print(a(5,2))
# Out:
# 7

# %% [markdown]
# #### Diff between lambda vs Normal Function
#
# - No name
# - lambda has no return value(infact,returns a function)
# - lambda is written in 1 line
# - not reusable
#
# Then why use lambda functions?<br>
# **They are used with HOF**

# %%
# check if a string has 'a'
a = lambda s:'a' in s
a('hello')
# Out:
# False

# %%
# odd or even
a= lambda num: 'even' if num%2==0 else 'odd'
a(2)
# Out:
# 'even'

# %% [markdown]
# ### Higher order functions
# - a function that recieves another function as parameter
# - OR a function that returns a function

# %%
def transform(f, L):
    output=[]
    for i in L:
        output.append(f(i))
    print(output)
    
L=[1,2,3,4]
transform(lambda a:a**2, L)
# Out:
# [1, 4, 9, 16]

# %%
# below are few functions based on lambda/usage of lambda

# %% [markdown]
# # MAP
# - creates a new list based on the given list using the logic given by lambda

# %%
# square the items of a list
list(map(lambda x:x**2, [1,2,3,4]))
# Out:
# [1, 4, 9, 16]

# %%
# odd/even labelling of list items

L=[1,2,3,4]
list(map(lambda num: 'even ' if num%2==0 else 'odd', L))
# Out:
# ['odd', 'even ', 'odd', 'even ']

# %%
# fetch names from a list of dict

users = [
    {
        'name':'Rahul',
        'age':45,
        'gender':'male'
    },
    {
        'name':'Nitish',
        'age':33,
        'gender':'male'
    },
    {
        'name':'Ankita',
        'age':50,
        'gender':'female'
    }
]

list(map(lambda x:x['name'], users))
# Out:
# ['Rahul', 'Nitish', 'Ankita']

# %%
# numbers greater than 5

L = [3,4,5,6,7]

list(map(lambda x:x>5,L)) # but we dont want it applied and shown to all elements in the list. we want it to filter and show only numbers who are 
# greater than 5. for that we have filter below
# Out:
# [False, False, False, True, True]

# %% [markdown]
# ### Filter

# %%
# numbers greater than 5

L = [3,4,5,6,7]
list(filter(lambda x:x>5,L))
# Out:
# [6, 7]

# %%
# fetch fruits starting with 'a'
fruits = ['apple','guava','cherry']
list(filter(lambda x:x.startswith('a'), fruits))
# Out:
# ['apple']

# %% [markdown]
# ### Reduce
# - performs operations on two numbers
# - reduce needs 2 parameters because it's always combining the running result with the next item.
# - reduce already works directly on a list — no need to wrap it in list() like you do with map and filter.

# %%
# sum of all item
import functools

functools.reduce(lambda x,y:x+y, [1,2,3,4,5])
# Out:
# 15

# %%
# find min
from functools import reduce
reduce(lambda x,y: x if x<y else y, [23,11,45,10,1])
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - map and filter accept a function as an argument
# - meaning you can pass in a pre-defined function instead of writing a lambda every time.

# %% [markdown]
# ![image.png](attachment:image.png)
